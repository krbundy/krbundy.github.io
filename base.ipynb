# %%
import numpy as np
import pandas as pd
import odbc
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
data_path = '../Data/COVID-19_Case_Surveillance_Public_Use_Data.csv'

covidDF = pd.read_csv(data_path, parse_dates=[0,1,2])

# %%
covidDF.head()
# Out:
#   cdc_report_dt pos_spec_dt   onset_dt             current_status   sex  \
# 0    2020-06-05  2020-04-08        NaT  Laboratory-confirmed case  Male
# 1    2020-06-05  2020-04-08 2020-04-08  Laboratory-confirmed case  Male
# 2    2020-05-13  2020-04-08 2020-05-03  Laboratory-confirmed case  Male
# 3    2020-04-11  2020-04-08        NaT  Laboratory-confirmed case  Male
# 4    2020-04-14  2020-04-08        NaT  Laboratory-confirmed case  Male
#
#      age_group Race and ethnicity (combined)  hosp_yn   icu_yn death_yn  \
# 0  0 - 9 Years           Black, Non-Hispanic  Unknown  Unknown  Unknown
# 1  0 - 9 Years           Black, Non-Hispanic       No  Unknown       No
# 2  0 - 9 Years           Black, Non-Hispanic      Yes      Yes       No
# 3  0 - 9 Years           Black, Non-Hispanic  Unknown  Unknown  Unknown
# 4  0 - 9 Years           Black, Non-Hispanic  Unknown  Unknown  Unknown
#
#   medcond_yn
# 0    Unknown
# 1    Unknown
# 2         No
# 3    Unknown
# 4        Yes

# %%
column_names = covidDF.columns.values.tolist()

# %%
covidDF['sex'].value_counts().plot(kind='bar',title='COVID-19 Cases by Sex')

# %%
covidDF['Race and ethnicity (combined)'].value_counts().plot(kind='bar')

# %%
covidDF['pos_spec_dt'].value_counts().plot()

# %%
covidDF.set_index('cdc_report_dt',inplace=True)

# %%
covidDF['cdc_report_dt'].value_counts().plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cdc_report_dt'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-f85626d3fa94> in <module>
# ...

# %%
sns.countplot(x="sex", data=covidDF);

# %%
covidDF['pos_spec_dt'].head()
# Out:
# cdc_report_dt
# 2020-06-05   2020-04-08
# 2020-06-05   2020-04-08
# 2020-05-13   2020-04-08
# 2020-04-11   2020-04-08
# 2020-04-14   2020-04-08
# Name: pos_spec_dt, dtype: datetime64[ns]
